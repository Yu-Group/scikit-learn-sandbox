# %%
import iRF_benchmarks_lib

# recall output file
file_in = 'specs/iRF_specs1.yaml'
specs = iRF_benchmarks_lib.yaml_to_dict(inp_yaml=file_in)

# specify output file
file_out = 'output/iRF_output1.yaml'
bm = iRF_benchmarks_lib.yaml_to_dict(inp_yaml=file_out)

# %%
# plot whatever you want
# third argument is x_axis, fourth argument is y_axis
iRF_benchmarks_lib.plot_bm(bm, specs, 'n_estimators', 'time')
iRF_benchmarks_lib.plot_bm(bm, specs, 'n_estimators', 'accuracy_score')
